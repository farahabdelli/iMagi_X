# %%
import pandas
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # data Johnny Alves

# %%
#importer les données

datajohnny = pd.read_csv('data/johny.csv',sep=";")
datajohnny
# Out:
#                   Date    airTemp  heaterSetpoint        orp   ph  \
# 0     14/07/2022 16:45  30.400000            27.0  735.50641  7.2
# 1     14/07/2022 17:00  30.400000            27.0  735.01495  7.2
# 2     14/07/2022 17:15  30.384144            27.0  733.98438  7.2
# 3     14/07/2022 17:30  30.333395            27.0  736.31604  7.2
# 4     14/07/2022 17:45  30.382420            27.0  737.98102  7.2
# ...                ...        ...             ...        ...  ...
# 5257  13/09/2022 23:00  22.633326            15.0  794.00000  7.1
# 5258  13/09/2022 23:15  22.633327            15.0  794.00000  7.1
# 5259  13/09/2022 23:30  22.661238            15.0  794.72076  7.1
# 5260  13/09/2022 23:45  22.600000            15.0  793.34937  7.1
# 5261  14/09/2022 00:00  22.600000            15.0  789.05133  7.1
#
#       treatmentChlore  treatmentPh  waterTemp
# 0                 NaN          NaN  27.200001
# 1                 NaN          NaN  27.200001
# ...

# %%
#choix des colonnes
data2johnny = datajohnny[["Date",	"airTemp",	"heaterSetpoint",	"orp",	"ph",	"waterTemp"]]

#intervalle de date 
data2johnny['Date'] = pd.to_datetime(data2johnny['Date'])  
start_date = '14/07/2022 07:00'
end_date   = '14/09/2022 20:00'
mask = (data2johnny['Date'] > start_date) & (data2johnny['Date'] <= end_date)
data2 = data2johnny.loc[mask]

#ajouter une colonne type pour indique le type de chaque valeur
data2airjohnny = data2johnny[["Date",	"airTemp"]]
data2airjohnny = data2airjohnny.rename(columns={'Date': 'Date', 'airTemp': 'value'})
data2airjohnny=data2airjohnny.set_index("Date")
data2airjohnny['type']='airTemp'

data2heater = data2johnny[["Date","heaterSetpoint"]]
data2heater = data2heater.rename(columns={'Date': 'Date', 'heaterSetpoint': 'value'})
data2heater=data2heater.set_index("Date")
data2heater['type'] = 'heaterSetpoint'

data2orpjohnny = data2johnny[["Date","orp"]]
data2orpjohnny = data2orpjohnny.rename(columns={'Date': 'Date', 'orp': 'value'})
data2orpjohnny=data2orpjohnny.set_index("Date")
data2orpjohnny['type'] = 'orp'

data2phjohnny = data2johnny[["Date",	"ph"]]
data2phjohnny = data2phjohnny.rename(columns={'Date': 'Date', 'ph': 'value'})
data2phjohnny=data2phjohnny.set_index("Date")
data2phjohnny['type'] = 'ph'

data2water = data2johnny[["Date","waterTemp"]]
data2water = data2water.rename(columns={'Date': 'Date', 'waterTemp': 'value'})
data2water=data2water.set_index("Date")
data2water['type'] = "waterTemp"

df_typejohnny = pandas.concat([data2airjohnny,data2heater,data2heater,data2orpjohnny,data2phjohnny  ,data2water ,],axis=0)
df_typejohnny = df_typejohnny.reset_index()

#datetime entre 8h et 18h
df_typejohnny['Date'] = pd.to_datetime(df_typejohnny['Date'])  
dfjohnny=df_typejohnny[(df_typejohnny['Date'].apply(lambda x : x.hour)>=8) & (df_typejohnny['Date'].apply(lambda x : x.hour)<=18)]


#moyenne des valeurs chaque 2h
dfjohnny['time'] = dfjohnny['Date'].dt.round('120min')
aggregation = {'valeur': ('value', 'mean')}
df_aggjohnny = dfjohnny.groupby(['time','type']).agg(**aggregation).reset_index()


#afficher le graphique
import plotly.express as px

fig = px.line(df_aggjohnny, x="time", y="valeur",color='type')
             


fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
         
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
# Out:
# C:\Users\FABDELLI\AppData\Local\Temp\ipykernel_12992\3502951262.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\FABDELLI\AppData\Local\Temp\ipykernel_12992\3502951262.py:46: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # data Amaury Sion

# %%
#importer les données

dataamaury = pd.read_csv('data/amaury.csv',sep=";")
dataamaury
#choix des colonnes
data2amaury = dataamaury[["Date",	"airTemp",	"heaterSetpoint",	"orp",	"ph","thirdTemp",	"waterTemp"]]

#intervalle de date 
data2amaury['Date'] = pd.to_datetime(data2['Date'])  
start_date = '14/07/2022 07:00'
end_date   = '14/09/2022 20:00'
mask = (data2amaury['Date'] > start_date) & (data2amaury['Date'] <= end_date)
data2amaury = data2amaury.loc[mask]

#ajouter une colonne type pour indique le type de chaque valeur
data2airamaury = data2amaury[["Date",	"airTemp"]]
data2airamaury = data2airamaury.rename(columns={'Date': 'Date', 'airTemp': 'value'})
data2airamaury=data2airamaury.set_index("Date")
data2airamaury['type']='airTemp'

data2heater = data2amaury[["Date","heaterSetpoint"]]
data2heater = data2heater.rename(columns={'Date': 'Date', 'heaterSetpoint': 'value'})
data2heater=data2heater.set_index("Date")
data2heater['type'] = 'heaterSetpoint'

data2orpamaury = data2amaury[["Date","orp"]]
data2orpamaury = data2orpamaury.rename(columns={'Date': 'Date', 'orp': 'value'})
data2orpamaury=data2orpamaury.set_index("Date")
data2orpamaury['type'] = 'orp'

data2phamaury = data2amaury[["Date",	"ph"]]
data2phamaury = data2phamaury.rename(columns={'Date': 'Date', 'ph': 'value'})
data2phamaury=data2phamaury.set_index("Date")
data2phamaury['type'] = 'ph'

data2third = data2amaury[["Date","thirdTemp"]]
data2third = data2third.rename(columns={'Date': 'Date', 'thirdTemp': 'value'})
data2third=data2third.set_index("Date")
data2third['type'] = 'thirdTemp'

data2water = data2amaury[["Date","waterTemp"]]
data2water = data2water.rename(columns={'Date': 'Date', 'waterTemp': 'value'})
data2water=data2water.set_index("Date")
data2water['type'] = "waterTemp"

df_typeamaury = pandas.concat([data2airamaury,data2heater,data2heater,data2orpamaury,data2phamaury  ,data2third ,data2water ,],axis=0)
df_typeamaury = df_typeamaury.reset_index()

#datetime entre 8h et 18h
df_typeamaury['Date'] = pd.to_datetime(df_typeamaury['Date'])  
dfamaury=df_typeamaury[(df_typeamaury['Date'].apply(lambda x : x.hour)>=8) & (df_typeamaury['Date'].apply(lambda x : x.hour)<=18)]


#moyenne des valeurs chaque 2h
dfamaury['time'] = dfamaury['Date'].dt.round('120min')
aggregation = {'valeur': ('value', 'mean')}
df_aggamaury = dfamaury.groupby(['time','type']).agg(**aggregation).reset_index()


#afficher le graphique
import plotly.express as px

fig = px.line(df_aggamaury, x="time", y="valeur",color='type')
             


fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
         
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
# Out:
# C:\Users\FABDELLI\AppData\Local\Temp\ipykernel_12992\1002766161.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\FABDELLI\AppData\Local\Temp\ipykernel_12992\1002766161.py:55: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Data Hervé Ricard

# %%
#importer les données

dataherve = pd.read_csv('data/herve.csv',sep=";")
dataherve
#choix des colonnes
data2herve = dataherve[["Date",	"airTemp",	"heaterSetpoint",	"orp",	"ph","waterTemp"]]

#intervalle de date 
data2herve['Date'] = pd.to_datetime(data2herve['Date'])  
start_date = '14/07/2022 07:00'
end_date   = '14/09/2022 20:00'
mask = (data2herve['Date'] > start_date) & (data2herve['Date'] <= end_date)
data2herve = data2herve.loc[mask]

#ajouter une colonne type pour indique le type de chaque valeur
data2airherve = data2herve[["Date",	"airTemp"]]
data2airherve = data2airherve.rename(columns={'Date': 'Date', 'airTemp': 'value'})
data2airherve=data2airherve.set_index("Date")
data2airherve['type']='airTemp'

data2heater = data2herve[["Date","heaterSetpoint"]]
data2heater = data2heater.rename(columns={'Date': 'Date', 'heaterSetpoint': 'value'})
data2heater=data2heater.set_index("Date")
data2heater['type'] = 'heaterSetpoint'

data2orpherve = data2herve[["Date","orp"]]
data2orpherve = data2orpherve.rename(columns={'Date': 'Date', 'orp': 'value'})
data2orpherve=data2orpherve.set_index("Date")
data2orpherve['type'] = 'orp'

data2phherve = data2herve[["Date",	"ph"]]
data2phherve = data2phherve.rename(columns={'Date': 'Date', 'ph': 'value'})
data2phherve=data2phherve.set_index("Date")
data2phherve['type'] = 'ph'


data2water = data2herve[["Date","waterTemp"]]
data2water = data2water.rename(columns={'Date': 'Date', 'waterTemp': 'value'})
data2water=data2water.set_index("Date")
data2water['type'] = "waterTemp"

df_typeherve = pandas.concat([data2airherve,data2heater,data2heater,data2orpherve,data2phherve ,data2water ,],axis=0)
df_typeherve = df_typeherve.reset_index()

#datetime entre 8h et 18h
df_typeherve['Date'] = pd.to_datetime(df_typeherve['Date'])  
dfherve=df_typeherve[(df_typeherve['Date'].apply(lambda x : x.hour)>=8) & (df_typeherve['Date'].apply(lambda x : x.hour)<=18)]


#moyenne des valeurs chaque 2h
dfherve['time'] = dfherve['Date'].dt.round('120min')
aggregation = {'valeur': ('value', 'mean')}
df_aggherve = dfherve.groupby(['time','type']).agg(**aggregation).reset_index()


#afficher le graphique
import plotly.express as px

fig = px.line(df_aggherve, x="time", y="valeur",color='type')
             


fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
         
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
# Out:
# C:\Users\FABDELLI\AppData\Local\Temp\ipykernel_12992\1587607137.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\FABDELLI\AppData\Local\Temp\ipykernel_12992\1587607137.py:51: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # data Chevalier Valérie

# %%
#importer les données

datavalérie = pd.read_csv('data/valérie.csv',sep=";")
datavalérie
#choix des colonnes
data2valérie = datavalérie[["Date",	"airTemp",	"heaterSetpoint",	"orp",	"ph","thirdTemp",	"waterTemp"]]

#intervalle de date 
data2valérie['Date'] = pd.to_datetime(data2valérie['Date'])  
start_date = '14/07/2022 07:00'
end_date   = '14/09/2022 20:00'
mask = (data2valérie['Date'] > start_date) & (data2valérie['Date'] <= end_date)
data2valérie = data2valérie.loc[mask]

#ajouter une colonne type pour indique le type de chaque valeur
data2airvalérie = data2valérie[["Date",	"airTemp"]]
data2airvalérie = data2airvalérie.rename(columns={'Date': 'Date', 'airTemp': 'value'})
data2airvalérie=data2airvalérie.set_index("Date")
data2airvalérie['type']='airTemp'

data2heater = data2valérie[["Date","heaterSetpoint"]]
data2heater = data2heater.rename(columns={'Date': 'Date', 'heaterSetpoint': 'value'})
data2heater=data2heater.set_index("Date")
data2heater['type'] = 'heaterSetpoint'

data2orpvalérie = data2valérie[["Date","orp"]]
data2orpvalérie = data2orpvalérie.rename(columns={'Date': 'Date', 'orp': 'value'})
data2orpvalérie=data2orpvalérie.set_index("Date")
data2orpvalérie['type'] = 'orp'

data2phvalérie = data2valérie[["Date",	"ph"]]
data2phvalérie = data2phvalérie.rename(columns={'Date': 'Date', 'ph': 'value'})
data2phvalérie=data2phvalérie.set_index("Date")
data2phvalérie['type'] = 'ph'

data2third = data2valérie[["Date","thirdTemp"]]
data2third = data2third.rename(columns={'Date': 'Date', 'thirdTemp': 'value'})
data2third=data2third.set_index("Date")
data2third['type'] = 'thirdTemp'

data2water = data2valérie[["Date","waterTemp"]]
data2water = data2water.rename(columns={'Date': 'Date', 'waterTemp': 'value'})
data2water=data2water.set_index("Date")
data2water['type'] = "waterTemp"

df_typevalérie = pandas.concat([data2airvalérie,data2heater,data2heater,data2orpvalérie,data2phvalérie  ,data2third ,data2water ,],axis=0)
df_typevalérie = df_typevalérie.reset_index()

#datetime entre 8h et 18h
df_typevalérie['Date'] = pd.to_datetime(df_typevalérie['Date'])  
dfvalérie=df_typevalérie[(df_typevalérie['Date'].apply(lambda x : x.hour)>=8) & (df_typevalérie['Date'].apply(lambda x : x.hour)<=18)]


#moyenne des valeurs chaque 2h
dfvalérie['time'] = dfvalérie['Date'].dt.round('120min')
aggregation = {'valeur': ('value', 'mean')}
df_aggvalérie = dfvalérie.groupby(['time','type']).agg(**aggregation).reset_index()


#afficher le graphique
import plotly.express as px

fig = px.line(df_aggvalérie, x="time", y="valeur",color='type')
             


fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
         
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
# Out:
# C:\Users\FABDELLI\AppData\Local\Temp\ipykernel_12992\2982346413.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\FABDELLI\AppData\Local\Temp\ipykernel_12992\2982346413.py:55: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Data François Cyril

# %%
#importer les données

datacyril = pd.read_csv('data/cyril.csv',sep=";")
datacyril
#choix des colonnes
data2cyril = datacyril[["Date",	"airTemp",	"heaterSetpoint",	"orp",	"ph",	"waterTemp"]]

#intervalle de date 
data2cyril['Date'] = pd.to_datetime(data2cyril['Date'])  
start_date = '14/07/2022 07:00'
end_date   = '14/09/2022 20:00'
mask = (data2cyril['Date'] > start_date) & (data2cyril['Date'] <= end_date)
data2cyril = data2cyril.loc[mask]

#ajouter une colonne type pour indique le type de chaque valeur
data2aircyril = data2cyril[["Date",	"airTemp"]]
data2aircyril = data2aircyril.rename(columns={'Date': 'Date', 'airTemp': 'value'})
data2aircyril=data2aircyril.set_index("Date")
data2aircyril['type']='airTemp'

data2heater = data2cyril[["Date","heaterSetpoint"]]
data2heater = data2heater.rename(columns={'Date': 'Date', 'heaterSetpoint': 'value'})
data2heater=data2heater.set_index("Date")
data2heater['type'] = 'heaterSetpoint'

data2orpcyril = data2cyril[["Date","orp"]]
data2orpcyril = data2orpcyril.rename(columns={'Date': 'Date', 'orp': 'value'})
data2orpcyril=data2orpcyril.set_index("Date")
data2orpcyril['type'] = 'orp'

data2phcyril = data2cyril[["Date",	"ph"]]
data2phcyril = data2phcyril.rename(columns={'Date': 'Date', 'ph': 'value'})
data2phcyril=data2phcyril.set_index("Date")
data2phcyril['type'] = 'ph'

"""data2third = data2[["Date","thirdTemp"]]
data2third = data2third.rename(columns={'Date': 'Date', 'thirdTemp': 'value'})
data2third=data2third.set_index("Date")
data2third['type'] = 'thirdTemp'
"""
data2water = data2cyril[["Date","waterTemp"]]
data2water = data2water.rename(columns={'Date': 'Date', 'waterTemp': 'value'})
data2water=data2water.set_index("Date")
data2water['type'] = "waterTemp"

df_typecyril = pandas.concat([data2aircyril,data2heater,data2heater,data2orpcyril,data2phcyril ,data2water ,],axis=0)
df_typecyril = df_typecyril.reset_index()

#datetime entre 8h et 18h
df_typecyril['Date'] = pd.to_datetime(df_typecyril['Date'])  
dfcyril=df_typecyril[(df_typecyril['Date'].apply(lambda x : x.hour)>=8) & (df_typecyril['Date'].apply(lambda x : x.hour)<=18)]


#moyenne des valeurs chaque 2h
dfcyril['time'] = dfcyril['Date'].dt.round('120min')
aggregation = {'valeur': ('value', 'mean')}
df_aggcyril = dfcyril.groupby(['time','type']).agg(**aggregation).reset_index()


#afficher le graphique
import plotly.express as px

fig = px.line(df_aggcyril, x="time", y="valeur",color='type')
             


fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
         
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
# Out:
# C:\Users\FABDELLI\AppData\Local\Temp\ipykernel_12992\1966818263.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\FABDELLI\AppData\Local\Temp\ipykernel_12992\1966818263.py:55: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # air temp

# %%
data2aircyril = data2cyril[["Date",	"airTemp"]]
data2aircyril = data2aircyril.rename(columns={'Date': 'Date', 'airTemp': 'value'})
data2aircyril=data2aircyril.set_index("Date")
data2aircyril['bassin']='cyril'

#ajouter une colonne type pour indique le type de chaque valeur
data2airvalérie = data2valérie[["Date",	"airTemp"]]
data2airvalérie = data2airvalérie.rename(columns={'Date': 'Date', 'airTemp': 'value'})
data2airvalérie=data2airvalérie.set_index("Date")
data2airvalérie['bassin']='valérie'

data2airherve = data2herve[["Date",	"airTemp"]]
data2airherve = data2airherve.rename(columns={'Date': 'Date', 'airTemp': 'value'})
data2airherve=data2airherve.set_index("Date")
data2airherve['bassin']='hervé'

data2airamaury = data2amaury[["Date",	"airTemp"]]
data2airamaury = data2airamaury.rename(columns={'Date': 'Date', 'airTemp': 'value'})
data2airamaury=data2airamaury.set_index("Date")
data2airamaury['bassin']='amaury'


data2airjohnny = data2johnny[["Date",	"airTemp"]]
data2airjohnny = data2airjohnny.rename(columns={'Date': 'Date', 'airTemp': 'value'})
data2airjohnny=data2airjohnny.set_index("Date")
data2airjohnny['bassin']='johnny'

# %%
dataair  = pandas.concat([data2aircyril,data2airvalérie,data2airherve,data2airamaury,data2airjohnny ],axis=0)
dataair = dataair.reset_index()

dataair['Date'] = pd.to_datetime(dataair['Date'])  
start_date = '14/07/2022 07:00'
end_date   = '14/09/2022 20:00'
mask = (dataair['Date'] > start_date) & (dataair['Date'] <= end_date)
dataair = dataair.loc[mask]
  
dataair=dataair[(dataair['Date'].apply(lambda x : x.hour)>=8) & (dataair['Date'].apply(lambda x : x.hour)<=18)]


#moyenne des valeurs chaque 2h
dataair['time'] = dataair['Date'].dt.round('120min')
aggregation = {'valeur': ('value', 'mean')}
df_aggair = dataair.groupby(['time','bassin']).agg(**aggregation).reset_index()


dataair
# Out:
#                      Date      value  bassin                time
# 3     2022-07-14 08:00:00  24.166838   cyril 2022-07-14 08:00:00
# 4     2022-07-14 08:15:00  24.566774   cyril 2022-07-14 08:00:00
# 5     2022-07-14 08:30:00  24.966616   cyril 2022-07-14 08:00:00
# 6     2022-07-14 08:45:00  25.399494   cyril 2022-07-14 08:00:00
# 7     2022-07-14 09:00:00  25.807281   cyril 2022-07-14 08:00:00
# ...                   ...        ...     ...                 ...
# 20004 2022-09-13 17:45:00  24.626297  johnny 2022-09-13 18:00:00
# 20005 2022-09-13 18:00:00  24.519543  johnny 2022-09-13 18:00:00
# 20006 2022-09-13 18:15:00  24.393269  johnny 2022-09-13 18:00:00
# 20007 2022-09-13 18:30:00  24.259983  johnny 2022-09-13 18:00:00
# 20008 2022-09-13 18:45:00  24.160082  johnny 2022-09-13 18:00:00
#
# [8376 rows x 4 columns]

# %%
#afficher le graphique
import plotly.express as px

fig = px.line(df_aggair, x="time", y="valeur",color='bassin')
             


fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
         
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()

# %%
fig.write_html('comparaisonAirTemp.html')

# %% [markdown]
# # cablage

# %%
data2orpjohnny = data2johnny[["Date","orp"]]
data2orpjohnny = data2orpjohnny.rename(columns={'Date': 'Date', 'orp': 'value'})
data2orpjohnny=  data2orpjohnny.set_index("Date")
data2orpjohnny['type'] = 'orp_johnny'
data2orpjohnny['bassin'] = 'johnny'

data2phjohnny = data2johnny[["Date",	"ph"]]
data2phjohnny = data2phjohnny.rename(columns={'Date': 'Date', 'ph': 'value'})
data2phjohnny=data2phjohnny.set_index("Date")
data2phjohnny['type'] = 'ph_johnny'
data2phjohnny['bassin'] = 'johnny'

data2orpherve = data2herve[["Date","orp"]]
data2orpherve = data2orpherve.rename(columns={'Date': 'Date', 'orp': 'value'})
data2orpherve=data2orpherve.set_index("Date")
data2orpherve['type'] = 'orp_herve'
data2orpherve['bassin'] = 'herve'

data2phherve = data2herve[["Date",	"ph"]]
data2phherve = data2phherve.rename(columns={'Date': 'Date', 'ph': 'value'})
data2phherve=data2phherve.set_index("Date")
data2phherve['type'] = 'ph_herve'
data2phherve['bassin'] = 'herve'

data2orpcyril = data2cyril[["Date","orp"]]
data2orpcyril = data2orpcyril.rename(columns={'Date': 'Date', 'orp': 'value'})
data2orpcyril=data2orpcyril.set_index("Date")
data2orpcyril['type'] = 'orp_cyril'
data2orpcyril['bassin'] = 'cyril'

data2phcyril = data2cyril[["Date",	"ph"]]
data2phcyril = data2phcyril.rename(columns={'Date': 'Date', 'ph': 'value'})
data2phcyril=data2phcyril.set_index("Date")
data2phcyril['type'] = 'ph_cyril'
data2phcyril['bassin'] = 'cyril'

data2orpvalérie = data2valérie[["Date","orp"]]
data2orpvalérie = data2orpvalérie.rename(columns={'Date': 'Date', 'orp': 'value'})
data2orpvalérie=data2orpvalérie.set_index("Date")
data2orpvalérie['type'] = 'orp_valérie'
data2orpvalérie['bassin'] = 'valérie'

data2phvalérie = data2valérie[["Date",	"ph"]]
data2phvalérie = data2phvalérie.rename(columns={'Date': 'Date', 'ph': 'value'})
data2phvalérie=data2phvalérie.set_index("Date")
data2phvalérie['type'] = 'ph_valérie'
data2phvalérie['bassin'] = 'valérie'


data2orpamaury = data2amaury[["Date","orp"]]
data2orpamaury = data2orpamaury.rename(columns={'Date': 'Date', 'orp': 'value'})
data2orpamaury=data2orpamaury.set_index("Date")
data2orpamaury['type'] = 'orp_amaury'
data2orpamaury['bassin'] = 'amaury'


data2phamaury = data2amaury[["Date",	"ph"]]
data2phamaury = data2phamaury.rename(columns={'Date': 'Date', 'ph': 'value'})
data2phamaury=data2phamaury.set_index("Date")
data2phamaury['type'] = 'ph_amaury'
data2phamaury['bassin'] = 'amaury'

# %%
data_orp  = pandas.concat([data2orpamaury,data2orpvalérie,data2orpcyril,data2orpherve,data2orpjohnny ],axis=0)
data_orp = data_orp.reset_index()

data_orp['Date'] = pd.to_datetime(data_orp['Date'])  
start_date = '14/07/2022 00:00'
end_date   = '14/09/2022 23:00'
mask = (data_orp['Date'] > start_date) & (data_orp['Date'] <= end_date)
data_orp = data_orp.loc[mask]

data_orp=data_orp[(data_orp['Date'].apply(lambda x : x.hour)>=1) & (data_orp['Date'].apply(lambda x : x.hour)<=23)]


#moyenne des valeurs chaque 2h
data_orp['time'] = data_orp['Date'].dt.round('15min')
aggregation = {'valeur': ('value', 'mean')}
df_aggorp = data_orp.groupby(['time','bassin']).agg(**aggregation).reset_index()

#afficher le graphique
import plotly.express as px

fig = px.line(df_aggorp, x="time", y="valeur",color='bassin')
             


fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
         
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()

# %%
fig.write_html('comparaisonORP.html')

# %%
data_ph  = pandas.concat([data2phamaury,data2phvalérie,data2phcyril,data2phherve,data2phjohnny ],axis=0)
data_ph = data_ph.reset_index()

data_ph['Date'] = pd.to_datetime(data_ph['Date'])  
start_date = '14/07/2022 07:00'
end_date   = '14/09/2022 20:00'
mask = (data_ph['Date'] > start_date) & (data_ph['Date'] <= end_date)
data_ph = data_ph.loc[mask]

data_ph=data_ph[(data_ph['Date'].apply(lambda x : x.hour)>=8) & (data_ph['Date'].apply(lambda x : x.hour)<=18)]


#moyenne des valeurs chaque 2h
data_ph['time'] = data_ph['Date'].dt.round('120min')
aggregation = {'valeur': ('value', 'mean')}
df_aggph = data_ph.groupby(['time','bassin']).agg(**aggregation).reset_index()

#afficher le graphique
import plotly.express as px

fig = px.line(df_aggph, x="time", y="valeur",color='bassin')
             


fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
         
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()

# %%
data_orp_ph  = pandas.concat([data2orpamaury,data2orpvalérie,data2orpcyril,data2orpherve,data2orpjohnny,data2phamaury,data2phvalérie,data2phcyril,data2phherve,data2phjohnny ],axis=0)
data_orp_ph = data_orp_ph.reset_index()

data_orp_ph['Date'] = pd.to_datetime(data_orp_ph['Date'])  
start_date = '14/07/2022 07:00'
end_date   = '14/09/2022 20:00'
mask = (data_orp_ph['Date'] > start_date) & (data_orp_ph['Date'] <= end_date)
data_orp_ph = data_orp_ph.loc[mask]

data_orp_ph=data_orp_ph[(data_orp_ph['Date'].apply(lambda x : x.hour)>=8) & (data_orp_ph['Date'].apply(lambda x : x.hour)<=18)]


#moyenne des valeurs chaque 2h
data_orp_ph['time'] = data_orp_ph['Date'].dt.round('120min')
aggregation = {'valeur': ('value', 'mean')}
df_aggph_orp = data_orp_ph.groupby(['time','type']).agg(**aggregation).reset_index()

#afficher le graphique
import plotly.express as px

fig = px.line(df_aggph_orp, x="time", y="valeur",color='type')
             


fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
         
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()

# %%
df_aggph_orp
# Out:
#                     time   bassin type      valeur
# 0    2022-07-14 08:00:00    cyril  orp  746.149988
# 1    2022-07-14 08:00:00    cyril   ph    7.400000
# 2    2022-07-14 08:00:00    herve  orp  771.211950
# 3    2022-07-14 08:00:00    herve   ph    7.200000
# 4    2022-07-14 10:00:00    cyril  orp  743.250646
# ...                  ...      ...  ...         ...
# 2319 2022-09-13 18:00:00    herve   ph    7.300000
# 2320 2022-09-13 18:00:00   johnny  orp  770.161733
# 2321 2022-09-13 18:00:00   johnny   ph    6.944784
# 2322 2022-09-13 18:00:00  valérie  orp  770.161733
# 2323 2022-09-13 18:00:00  valérie   ph    6.944784
#
# [2324 rows x 4 columns]
